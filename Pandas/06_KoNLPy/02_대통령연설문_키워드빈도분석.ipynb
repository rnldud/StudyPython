# %%
# 워드클라우드 순서
# 0. 전처리...
#1. 단어 추출
#2. 단어들의 빈도 
#3. 시각화(워드클라우드)
#4. 단어간 연관성 분석: 네트워크분석..

# %%
from konlpy.tag import Okt

# %%
from collections import Counter

# %%
import matplotlib.pyplot as plt

# %%
from wordcloud import WordCloud

# %%
font_path = "c:/Windows/Fonts/malgun.ttf"

# %%
word = Okt()

# %%
text = "한국어 분석을 시작합니다."
print(word.nouns(text))
# Out:
# ['한국어', '분석', '시작']

# %%
#문장단위로 저장시 """ 쌍따옴표 3개 """
report = """
존경하는 국민 여러분.

오늘 저는 대한민국의 제16대 대통령에 취임하기 위해 이 자리에 섰습니다. 국민 여러분의 위대한 선택으로, 저는 대한민국의 새 정부를 운영할 영광스러운 책임을 맡게 되었습니다.

국민 여러분께 뜨거운 감사를 올리면서, 이 벅찬 소명을 국민 여러분과 함께 완수해 나갈 것임을 약속드립니다.

아울러 이 자리에 참석해 주신 김대중 대통령을 비롯한 전임 대통령 여러분, 고이즈미 준이치로일본 총리를 비롯한 세계 각국의 경축 사절과 내외 귀빈 여러분께도 심심한 감사를 드립니다.

특별히 이 자리를 빌려, 대구 지하철 참사 희생자 여러분의 명복을 빌면서, 유가족 여러분께도 깊은 위로를 드립니다. 다시는 이런 불행이 되풀이되지 않게, 재난관리체계를 전면 점검하고 획기적으로 개선해 안전한 사회를 만들도록 최선을 다하겠습니다.

국민 여러분.

우리의 역사는 도전과 극복의 연속이었습니다. 열강의 틈에 놓인 한반도에서 숱한 고난을 이겨내고, 반만년동안 민족의 자존과 독자적 문화를 지켜왔습니다. 해방 이후에는 분단과 전쟁과 가난을 딛고, 반세기만에 세계 열두 번째의 경제 강국을 건설했습니다.

우리는 농경시대에서 산업화를 거쳐 지식정보화 시대에 성공적으로 진입했습니다. 그러나 지금 우리는 다시 세계사적 전환점에 직면했습니다. 도약이냐 후퇴냐, 평화냐 긴장이냐의 갈림길에 서 있습니다.

세계의 안보 상황이 불안합니다. 이라크 정세가 긴박합니다. 특히 북한 핵 문제를 둘러싼 국제사회의 우려가 고조되고 있습니다. 이럴수록 우리는 평화를 지키고 더욱 굳건히 뿌리내리게 해야 합니다. 대외 경제 환경도 어려워지고 있습니다. 선진국들은 끝없이 새로운 영역을 개척하며 뻗어가고 있습니다. 후발국들은 무섭게 추격해 옵니다. 우리는 새로운 성장 동력과 발전 전략을 요구받고 있습니다. 우리 사회 내부에도 국가의 명운을 결정지을 많은 문제들이 가로놓여 있습니다. 이들 과제는 국민 여러분의 지혜와 결단을 기다리고 있습니다.

이 모든 도전을 극복해야 합니다. 우리는 해낼 수 있습니다. 우리 국민이 힘을 합치면, 못할 것이 없습니다. 그런 저력으로 우리는 외환 위기를 세계에서 가장 빨리 벗어났습니다. 지난해에는 월드컵 4강 신화를 창조했습니다. 대통령 선거의 모든 과정을 통해 참여 민주주의의 꽃을 피웠습니다.

존경하는 국민 여러분.

이제 우리의 미래는 한반도에 갇혀 있을 수 없습니다. 우리 앞에는 동북아 시대가 도래하고 있습니다. 근대 이후 세계의 변방에 머물던 동북아가, 이제 세계 경제의 새로운 활력으로 떠올랐습니다. 21세기는 동북아 시대가 될 것이라는 세계 석학들의 예측이 착착 현실로 나타나고 있습니다. 동북아의 경제규모는 세계의 5분의 1을 차지합니다. 한, 중, 일3국에만 유럽연합의 네 배가 넘는 인구가 살고 있습니다.

우리 한반도는 동북아의 중심에 자리잡고 있습니다. 한반도는 중국과일본, 대륙과 해양을 연결하는 다리입니다. 이런 지정학적 위치가 지난날에는 우리에게 고통을 주었습니다. 그러나 오늘날에는 오히려 기회를 주고 있습니다. 21세기 동북아 시대의 중심적 역할을 우리에게 요구하고 있는 것입니다.

우리는 고급 두뇌와 창의력, 세계일류의 정보화 기반을 갖고 있습니다. 인천공항, 부산항, 광양항과 고속철도 등 하늘과 바다와 땅의 물류기반도 구비해 가고 있습니다. 21세기 동북아 시대를 주도적으로 열어 나갈 수 있는 기본적 조건을 갖추어 가고 있습니다. 한반도는 동북아의 물류와 금융의 중심지로 거듭날 수 있습니다.

동북아 시대는 경제에서 출발합니다. 동북아에 '번영의 공동체'를 이룩하고 이를 통해 세계의 번영에 기여해야 합니다. 그리고 언젠가는 `평화의 공동체'로 발전해야 합니다. 지금의 유럽연합과 같은 평화와 공생의 질서가 동북아에도 구축되게 하는 것이 저의 오랜 꿈입니다. 그렇게 되어야 동북아 시대는 완성됩니다. 그런 날이 가까워지도록 저는 혼신의 노력을 다할 것임을 굳게 약속드립니다.

국민 여러분.

진정한 동북아 시대를 열자면 먼저 한반도에 평화가 제도적으로 정착되어야 합니다. 한반도가 지구상의 마지막 냉전지대로 남은 것은 20세기의 불행한 유산입니다. 그런 한반도가 21세기에는 세계를 향해 평화를 발신하는 평화지대로 바뀌어야 합니다. 유라시아 대륙과 태평양을 잇는 동북아의 평화로운 관문으로 새롭게 태어나야 합니다. 부산에서 파리행 기차표를 사서 평양, 신의주, 중국, 몽골, 러시아를 거쳐 유럽의 한복판에 도착하는 날을 앞당겨야 합니다.

이제까지 우리는 한반도의 평화를 증진시키기 위해 많은 노력을 기울였습니다. 그 성과는 괄목할 만합니다. 남북한 사이에 사람과 물자의 교류가일상적인일처럼 빈번해졌습니다. 하늘과 바다와 땅의 길이 모두 열렸습니다. 그러나 정책의 추진 과정에서는 더욱 광범위한 국민적 합의를 얻어야 한다는 과제를 남겼습니다. 저는 그동안의 성과를 계승하고 발전시키면서, 정책의 추진방식은 개선해 나가고자 합니다.

저는 한반도 평화증진과 공동번영을 목표로 하는 '평화번영정책'을, 몇가지 원칙을 가지고 추진해 나가겠습니다.

첫째, 모든 현안은 대화를 통해 풀도록 하겠습니다.

둘째, 상호신뢰를 우선하고 호혜주의를 실천해 나가겠습니다.

셋째, 남북 당사자 원칙에 기초해 원활한 국제협력을 추구하겠습니다.

넷째, 대내외적 투명성을 높이고 국민참여를 확대하며 초당적 협력을 얻겠습니다. 국민과 함께하는 '평화번영정책'이 되도록 하겠습니다.

북한의 핵무기 개발 의혹은 한반도를 비롯한 동북아와 세계의 평화에 중대한 위협이 되고 있습니다. 북한의 핵 개발은 용인될 수 없습니다. 북한은 핵 개발 계획을 포기해야 합니다. 북한이 핵 개발 계획을 포기한다면, 국제사회는 북한이 원하는 많은 것을 제공할 것입니다. 북한은 핵무기를 보유할 것인지, 체제안전과 경제지원을 약속받을 것인지를 선택해야 합니다.

아울러 저는 북한 핵 문제가 대화를 통해 평화적으로 해결되어야한다는 점을 거듭 강조하고자 합니다. 어떤 형태로든 군사적 긴장이 고조되어서는 안 됩니다. 북한 핵 문제가 대화를 통해 해결되도록, 우리는 미국,일본과의 공조를 강화할 것입니다. 중국, 러시아, 유럽연합 등과도 긴밀하게 협력해 나가겠습니다.

올해는 한미동맹 50주년입니다. 한미동맹은 우리의 안전보장과 경제발전에 크게 기여해 왔습니다. 우리 국민은 이에 대해 깊이 감사하고 있습니다. 우리는 한미동맹을 소중히 발전시켜 나갈 것입니다. 호혜평등의 관계로 더욱 성숙시켜 나갈 것입니다. 전통우방을 비롯한 다른 국가들과의 관계도 확대해 나가겠습니다.

국민 여러분.

동북아 시대를 열고, 한반도에 평화를 정착시키려면, 우리 사회가 건강하고 미래지향적이어야 합니다. 힘과 비전을 가져야 합니다. 그러자면 개혁과 통합을 위한 지속적 노력이 필요합니다. 개혁은 성장의 동력이고, 통합은 도약의 디딤돌입니다.

새 정부는 개혁과 통합을 바탕으로, 국민과 함께 하는 민주주의, 더불어 사는 균형발전사회, 평화와 번영의 동북아시대를 열어 나갈 것입니다. 이러한 목표로 가기 위해 저는 원칙과 신뢰, 공정과 투명, 대화와 타협, 분권과 자율을 새 정부 국정운영의 좌표로 삼고자 합니다.

우리는 각 분야의 새로운 성장 동력을 창출해야 합니다. 외환위기를 초래했던 제반 요인들은 아직도 극복해야할 과제로 남아 있습니다. 시장과 제도를 세계기준에 맞게 공정하고 투명하게 개혁해, 기업하기 좋은 나라, 투자하고 싶은 나라로 만들고자 합니다.

정치부터 바뀌어야 합니다. 진정으로 국민이 주인인 정치가 구현되어야 합니다. 당리당략보다 국리민복을 우선하는 정치풍토가 조성되어야 합니다. 대결과 갈등이 아니라 대화와 타협으로 문제를 푸는 정치문화가 자리잡았으면 합니다. 저부터 야당과 대화하고 타협하겠습니다.

과학기술을 부단히 혁신해 '제2의 과학기술 입국'을 이루겠습니다. 지식정보화 기반을 지속적으로 확충하고 신산업을 육성하고자 합니다. 문화를 함양하고 문화산업의 발전도 적극 지원하겠습니다.

이러한 국가목표에 부응할 수 있도록 교육도 혁신되어야 합니다. 우리 아이들이 입시지옥에서 벗어나 저마다의 소질과 창의력을 마음껏 발휘할 수 있게 해주어야 합니다.

경제의 지속적 성장을 위해서도, 사회의 건강을 위해서도 부정부패를 없애야 합니다. 이를 위한 구조적 제도적 대안을 모색하겠습니다. 특히 사회지도층의 뼈를 깎는 성찰을 요망합니다.

중앙 집권과 수도권 집중은 국가의 미래를 위해 더 이상 방치할 수 없습니다. 지방분권과 국가균형발전은 미룰 수 없는 과제가 되었습니다. 중앙과 지방은 조화와 균형을 이루며 발전해야 합니다. 지방은 자신의 미래를 자율적으로 설계하고, 중앙은 이를 도와야 합니다. 저는 비상한 결의로 이를 추진해 나갈 것입니다.

국민통합은 이 시대의 가장 중요한 숙제입니다. 지역구도를 완화하기 위해 새 정부는 지역탕평 인사를 포함한 가능한 모든 조치를 취해 나갈 것입니다. 소득격차를 비롯한 계층간 격차를 좁히기 위해 교육과 세제 등의 개선을 강구하고자 합니다. 노사화합과 협력의 문화를 이루도록 노사 여러분과 함께 최선을 다하겠습니다.

노약자를 비롯한 소외받는 사람들에게 더 많은 관심을 기울이는 따뜻한 사회를 만들어야 합니다. 이를 위해 복지정책을 내실화하고자 합니다. 모든 종류의 불합리한 차별을 없애 나가겠습니다. 양성평등사회를 지향해 나가겠습니다. 개방화 시대를 맞아 농어업과 농어민을 위한 대책을 강구하겠습니다. 고령사회의 도래에 대한 준비에도 소홀함이 없도록 하겠습니다.

반칙과 특권이 용납되는 시대는 이제 끝나야 합니다. 정의가 패배하고 기회주의자가 득세하는 굴절된 풍토는 청산되어야 합니다. 원칙을 바로 세워 신뢰사회를 만듭시다. 정정당당하게 노력하는 사람이 성공하는 사회로 나아갑시다. 정직하고 성실한 대다수 국민이 보람을 느끼게 해드려야 합니다.

존경하는 국민 여러분.

오랜 세월동안 우리는 변방의 역사를 살아왔습니다. 때로는 자신의 운명을 스스로 결정하지 못하는 의존의 역사를 강요받기도 했습니다. 그러나 이제 우리는 새로운 전기를 맞았습니다. 21세기 동북아 시대의 중심국가로 웅비할 기회가 우리에게 찾아 왔습니다. 우리는 이 기회를 살려 나가야 합니다.

우리에게는 수많은 도전을 극복한 저력이 있습니다. 위기마저도 기회로 만드는 지혜가 있습니다. 그런 지혜와 저력으로 오늘 우리에게 닥친 도전을 극복합시다. 오늘 우리가 선조들을 기리는 것처럼, 먼 훗날 후손들이 오늘의 우리를 자랑스러운 조상으로 기억하게 합시다.

우리는 마음만 합치면 기적을 이루어 내는 국민입니다. 우리 모두 마음을 모읍시다. 평화와 번영과 도약의 새 역사를 만드는 이 위대한 도정에 모두 동참합시다. 항상 국민 여러분과 함께 하겠습니다.

감사합니다.
"""

# %%
report
# Out:
# "\n존경하는 국민 여러분.\n\n오늘 저는 대한민국의 제16대 대통령에 취임하기 위해 이 자리에 섰습니다. 국민 여러분의 위대한 선택으로, 저는 대한민국의 새 정부를 운영할 영광스러운 책임을 맡게 되었습니다.\n\n국민 여러분께 뜨거운 감사를 올리면서, 이 벅찬 소명을 국민 여러분과 함께 완수해 나갈 것임을 약속드립니다.\n\n아울러 이 자리에 참석해 주신 김대중 대통령을 비롯한 전임 대통령 여러분, 고이즈미 준이치로일본 총리를 비롯한 세계 각국의 경축 사절과 내외 귀빈 여러분께도 심심한 감사를 드립니다.\n\n특별히 이 자리를 빌려, 대구 지하철 참사 희생자 여러분의 명복을 빌면서, 유가족 여러분께도 깊은 위로를 드립니다. 다시는 이런 불행이 되풀이되지 않게, 재난관리체계를 전면 점검하고 획기적으로 개선해 안전한 사회를 만들도록 최선을 다하겠습니다.\n\n국민 여러분.\n\n우리의 역사는 도전과 극복의 연속이었습니다. 열강의 틈에 놓인 한반도에서 숱한 고난을 이겨내고, 반만년동안 민족의 자존과 독자적 문화를 지켜왔습니다. 해방 이후에는 분단과 전쟁과 가난을 딛고, 반세기만에 세계 열두 번째의 경제 강국을 건설했습니다.\n\n우리는 농경시대에서 산업화를 거쳐 지식정보화 시대에 성공적으로 진입했습니다. 그러나 지금 우리는 다시 세계사적 전환점에 직면했습니다. 도약이냐 후퇴냐, 평화냐 긴장이냐의 갈림길에 서 있습니다.\n\n세계의 안보 상황이 불안합니다. 이라크 정세가 긴박합니다. 특히 북한 핵 문제를 둘러싼 국제사회의 우려가 고조되고 있습니다. 이럴수록 우리는 평화를 지키고 더욱 굳건히 뿌리내리게 해야 합니다. 대외 경제 환경도 어려워지고 있습니다. 선진국들은 끝없이 새로운 영역을 개척하며 뻗어가고 있습니다. 후발국들은 무섭게 추격해 옵니다. 우리는 새로운 성장 동력과 발전 전략을 요구받고 있습니다. 우리 사회 내부에도 국가의 명운을 결정지을 많은 문제들이 가로놓여 있습니다. 이들 과제는 국민 여러분의 지혜와 결단을 기다리고 있습니다.\n\n이 모든 도전을 극복해야 합니다. 우리는 해낼 수 있습니다. 우리 국민이 힘을 합치면, 못할 것이 없습니다. 그런 저력으로 우리는 외환 위기를 세계에서 가장 빨리 벗어났습니다. 지난해에는 월드컵 4강 신화를 창조했습니다. 대통령 선거의 모든 과정을 통해 참여 민주주의의 꽃을 피웠습니다.\n\n존경하는 국민 여러분.\n\n이제 우리의 미래는 한반도에 갇혀 있을 수 없습니다. 우리 앞에는 동북아 시대가 도래하고 있습니다. 근대 이후 세계의 변방에 머물던 동북아가, 이제 세계 경제의 새로운 활력으로 떠올랐습니다. 21세기는 동북아 시대가 될 것이라는 세계 석학들의 예측이 착착 현실로 나타나고 있습니다. 동북아의 경제규모는 세계의 5분의 1을 차지합니다. 한, 중, 일3국에만 유럽연합의 네 배가 넘는 인구가 살고 있습니다.\n\n우리 한반도는 동북아의 중심에 자리잡고 있습니다. 한반도는 중국과일본, 대륙과 해양을 연결하는 다리입니다. 이런 지정학적 위치가 지난날에는 우리에게 고통을 주었습니다. 그러나 오늘날에는 오히려 기회를 주고 있습니다. 21세기 동북아 시대의 중심적 역할을 우리에게 요구하고 있는 것입니다.\n\n우리는 고급 두뇌와 창의력, 세계일류의 정보화 기반을 갖고 있습니다. 인천공항, 부산항, 광양항과 고속철도 등 하늘과 바다와 땅의 물류기반도 구비해 가고 있습니다. 21세기 동북아 시대를 주도적으로 열어 나갈 수 있는 기본적 조건을 갖추어 가고 있습니다. 한반도는 동북아의 물류와 금융의 중심지로 거듭날 수 있습니다.\n\n동북아 시대는 경제에서 출발합니다. 동북아에 '번영의 공동체'를 이룩하고 이를 통해 세계의 번영에 기여해야 합니다. 그리고 언젠가는 `평화의 공동체'로 발전해야 합니다. 지금의 유럽연합과 같은 평화와 공생의 질서가 동북아에도 구축되게 하는 것이 저의 오랜 꿈입니다. 그렇게 되어야 동북아 시대는 완성됩니다. 그런 날이 가까워지도록 저는 혼신의 노력을 다할 것임을 굳게 약속드립니다.\n\n국민 여러분.\n\n진정한 동북아 시대를 열자면 먼저 한반도에 평화가 제도적으로 정착되어야 합니다. 한반도가 지구상의 마지막 냉전지대로 남은 것은 20세기의 불행한 유산입니다. 그런 한반도가 21세기에는 세계를 향해 평화를 발신하는 평화지대로 바뀌어야 합니다. 유라시아 대륙과 태평양을 잇는 동북아의 평화로운 관문으로 새롭게 태어나야 합니다. 부산에서 파리행 기차표를 사서 평양, 신의주, 중국, 몽골, 러시아를 거쳐 유럽의 한복판에 도착하는 날을 앞당겨야 합니다.\n\n이제까지 우리는 한반도의 평화를 증진시키기 위해 많은 노력을 기울였습니다. 그 성과는 괄목할 만합니다. 남북한 사이에 사람과 물자의 교류가일상적인일처럼 빈번해졌습니다. 하늘과 바다와 땅의 길이 모두 열렸습니다. 그러나 정책의 추진 과정에서는 더욱 광범위한 국민적 합의를 얻어야 한다는 과제를 남겼습니다. 저는 그동안의 성과를 계승하고 발전시키면서, 정책의 추진방식은 개선해 나가고자 합니다.\n\n저는 한반도 평화증진과 공동번영을 목표로 하는 '평화번영정책'을, 몇가지 원칙을 가지고 추진해 나가겠습니다.\n\n첫째, 모든 현안은 대화를 통해 풀도록 하겠습니다.\n\n둘째, 상호신뢰를 우선하고 호혜주의를 실천해 나가겠습니다.\n\n셋째, 남북 당사자 원칙에 기초해 원활한 국제협력을 추구하겠습니다.\n\n넷째, 대내외적 투명성을 높이고 국민참여를 확대하며 초당적 협력을 얻겠습니다. 국민과 함께하는 '평화번영정책'이 되도록 하겠습니다.\n\n북한의 핵무기 개발 의혹은 한반도를 비롯한 동북아와 세계의 평화에 중대한 위협이 되고 있습니다. 북한의 핵 개발은 용인될 수 없습니다. 북한은 핵 개발 계획을 포기해야 합니다. 북한이 핵 개발 계획을 포기한다면, 국제사회는 북한이 원하는 많은 것을 제공할 것입니다. 북한은 핵무기를 보유할 것인지, 체제안전과 경제지원을 약속받을 것인지를 선택해야 합니다.\n\n아울러 저는 북한 핵 문제가 대화를 통해 평화적으로 해결되어야한다는 점을 거듭 강조하고자 합니다. 어떤 형태로든 군사적 긴장이 고조되어서는 안 됩니다. 북한 핵 문제가 대화를 통해 해결되도록, 우리는 미국,일본과의 공조를 강화할 것입니다. 중국, 러시아, 유럽연합 등과도 긴밀하게 협력해 나가겠습니다.\n\n올해는 한미동맹 50주년입니다. 한미동맹은 우리의 안전보장과 경제발전에 크게 기여해 왔습니다. 우리 국민은 이에 대해 깊이 감사하고 있습니다. 우리는 한미동맹을 소중히 발전시켜 나갈 것입니다. 호혜평등의 관계로 더욱 성숙시켜 나갈 것입니다. 전통우방을 비롯한 다른 국가들과의 관계도 확대해 나가겠습니다.\n\n국민 여러분.\n\n동북아 시대를 열고, 한반도에 평화를 정착시키려면, 우리 사회가 건강하고 미래지향적이어야 합니다. 힘과 비전을 가져야 합니다. 그러자면 개혁과 통합을 위한 지속적 노력이 필요합니다. 개혁은 성장의 동력이고, 통합은 도약의 디딤돌입니다.\n\n새 정부는 개혁과 통합을 바탕으로, 국민과 함께 하는 민주주의, 더불어 사는 균형발전사회, 평화와 번영의 동북아시대를 열어 나갈 것입니다. 이러한 목표로 가기 위해 저는 원칙과 신뢰, 공정과 투명, 대화와 타협, 분권과 자율을 새 정부 국정운영의 좌표로 삼고자 합니다.\n\n우리는 각 분야의 새로운 성장 동력을 창출해야 합니다. 외환위기를 초래했던 제반 요인들은 아직도 극복해야할 과제로 남아 있습니다. 시장과 제도를 세계기준에 맞게 공정하고 투명하게 개혁해, 기업하기 좋은 나라, 투자하고 싶은 나라로 만들고자 합니다.\n\n정치부터 바뀌어야 합니다. 진정으로 국민이 주인인 정치가 구현되어야 합니다. 당리당략보다 국리민복을 우선하는 정치풍토가 조성되어야 합니다. 대결과 갈등이 아니라 대화와 타협으로 문제를 푸는 정치문화가 자리잡았으면 합니다. 저부터 야당과 대화하고 타협하겠습니다.\n\n과학기술을 부단히 혁신해 '제2의 과학기술 입국'을 이루겠습니다. 지식정보화 기반을 지속적으로 확충하고 신산업을 육성하고자 합니다. 문화를 함양하고 문화산업의 발전도 적극 지원하겠습니다.\n\n이러한 국가목표에 부응할 수 있도록 교육도 혁신되어야 합니다. 우리 아이들이 입시지옥에서 벗어나 저마다 ...

# %%
# 특수문자 "\n" 제거하여 추출 
repot = report.replace("\n","")

# %%
repot
# Out:
# "존경하는 국민 여러분.오늘 저는 대한민국의 제16대 대통령에 취임하기 위해 이 자리에 섰습니다. 국민 여러분의 위대한 선택으로, 저는 대한민국의 새 정부를 운영할 영광스러운 책임을 맡게 되었습니다.국민 여러분께 뜨거운 감사를 올리면서, 이 벅찬 소명을 국민 여러분과 함께 완수해 나갈 것임을 약속드립니다.아울러 이 자리에 참석해 주신 김대중 대통령을 비롯한 전임 대통령 여러분, 고이즈미 준이치로일본 총리를 비롯한 세계 각국의 경축 사절과 내외 귀빈 여러분께도 심심한 감사를 드립니다.특별히 이 자리를 빌려, 대구 지하철 참사 희생자 여러분의 명복을 빌면서, 유가족 여러분께도 깊은 위로를 드립니다. 다시는 이런 불행이 되풀이되지 않게, 재난관리체계를 전면 점검하고 획기적으로 개선해 안전한 사회를 만들도록 최선을 다하겠습니다.국민 여러분.우리의 역사는 도전과 극복의 연속이었습니다. 열강의 틈에 놓인 한반도에서 숱한 고난을 이겨내고, 반만년동안 민족의 자존과 독자적 문화를 지켜왔습니다. 해방 이후에는 분단과 전쟁과 가난을 딛고, 반세기만에 세계 열두 번째의 경제 강국을 건설했습니다.우리는 농경시대에서 산업화를 거쳐 지식정보화 시대에 성공적으로 진입했습니다. 그러나 지금 우리는 다시 세계사적 전환점에 직면했습니다. 도약이냐 후퇴냐, 평화냐 긴장이냐의 갈림길에 서 있습니다.세계의 안보 상황이 불안합니다. 이라크 정세가 긴박합니다. 특히 북한 핵 문제를 둘러싼 국제사회의 우려가 고조되고 있습니다. 이럴수록 우리는 평화를 지키고 더욱 굳건히 뿌리내리게 해야 합니다. 대외 경제 환경도 어려워지고 있습니다. 선진국들은 끝없이 새로운 영역을 개척하며 뻗어가고 있습니다. 후발국들은 무섭게 추격해 옵니다. 우리는 새로운 성장 동력과 발전 전략을 요구받고 있습니다. 우리 사회 내부에도 국가의 명운을 결정지을 많은 문제들이 가로놓여 있습니다. 이들 과제는 국민 여러분의 지혜와 결단을 기다리고 있습니다.이 모든 도전을 극복해야 합니다. 우리는 해낼 수 있습니다. 우리 국민이 힘을 합치면, 못할 것이 없습니다. 그런 저력으로 우리는 외환 위기를 세계에서 가장 빨리 벗어났습니다. 지난해에는 월드컵 4강 신화를 창조했습니다. 대통령 선거의 모든 과정을 통해 참여 민주주의의 꽃을 피웠습니다.존경하는 국민 여러분.이제 우리의 미래는 한반도에 갇혀 있을 수 없습니다. 우리 앞에는 동북아 시대가 도래하고 있습니다. 근대 이후 세계의 변방에 머물던 동북아가, 이제 세계 경제의 새로운 활력으로 떠올랐습니다. 21세기는 동북아 시대가 될 것이라는 세계 석학들의 예측이 착착 현실로 나타나고 있습니다. 동북아의 경제규모는 세계의 5분의 1을 차지합니다. 한, 중, 일3국에만 유럽연합의 네 배가 넘는 인구가 살고 있습니다.우리 한반도는 동북아의 중심에 자리잡고 있습니다. 한반도는 중국과일본, 대륙과 해양을 연결하는 다리입니다. 이런 지정학적 위치가 지난날에는 우리에게 고통을 주었습니다. 그러나 오늘날에는 오히려 기회를 주고 있습니다. 21세기 동북아 시대의 중심적 역할을 우리에게 요구하고 있는 것입니다.우리는 고급 두뇌와 창의력, 세계일류의 정보화 기반을 갖고 있습니다. 인천공항, 부산항, 광양항과 고속철도 등 하늘과 바다와 땅의 물류기반도 구비해 가고 있습니다. 21세기 동북아 시대를 주도적으로 열어 나갈 수 있는 기본적 조건을 갖추어 가고 있습니다. 한반도는 동북아의 물류와 금융의 중심지로 거듭날 수 있습니다.동북아 시대는 경제에서 출발합니다. 동북아에 '번영의 공동체'를 이룩하고 이를 통해 세계의 번영에 기여해야 합니다. 그리고 언젠가는 `평화의 공동체'로 발전해야 합니다. 지금의 유럽연합과 같은 평화와 공생의 질서가 동북아에도 구축되게 하는 것이 저의 오랜 꿈입니다. 그렇게 되어야 동북아 시대는 완성됩니다. 그런 날이 가까워지도록 저는 혼신의 노력을 다할 것임을 굳게 약속드립니다.국민 여러분.진정한 동북아 시대를 열자면 먼저 한반도에 평화가 제도적으로 정착되어야 합니다. 한반도가 지구상의 마지막 냉전지대로 남은 것은 20세기의 불행한 유산입니다. 그런 한반도가 21세기에는 세계를 향해 평화를 발신하는 평화지대로 바뀌어야 합니다. 유라시아 대륙과 태평양을 잇는 동북아의 평화로운 관문으로 새롭게 태어나야 합니다. 부산에서 파리행 기차표를 사서 평양, 신의주, 중국, 몽골, 러시아를 거쳐 유럽의 한복판에 도착하는 날을 앞당겨야 합니다.이제까지 우리는 한반도의 평화를 증진시키기 위해 많은 노력을 기울였습니다. 그 성과는 괄목할 만합니다. 남북한 사이에 사람과 물자의 교류가일상적인일처럼 빈번해졌습니다. 하늘과 바다와 땅의 길이 모두 열렸습니다. 그러나 정책의 추진 과정에서는 더욱 광범위한 국민적 합의를 얻어야 한다는 과제를 남겼습니다. 저는 그동안의 성과를 계승하고 발전시키면서, 정책의 추진방식은 개선해 나가고자 합니다.저는 한반도 평화증진과 공동번영을 목표로 하는 '평화번영정책'을, 몇가지 원칙을 가지고 추진해 나가겠습니다.첫째, 모든 현안은 대화를 통해 풀도록 하겠습니다.둘째, 상호신뢰를 우선하고 호혜주의를 실천해 나가겠습니다.셋째, 남북 당사자 원칙에 기초해 원활한 국제협력을 추구하겠습니다.넷째, 대내외적 투명성을 높이고 국민참여를 확대하며 초당적 협력을 얻겠습니다. 국민과 함께하는 '평화번영정책'이 되도록 하겠습니다.북한의 핵무기 개발 의혹은 한반도를 비롯한 동북아와 세계의 평화에 중대한 위협이 되고 있습니다. 북한의 핵 개발은 용인될 수 없습니다. 북한은 핵 개발 계획을 포기해야 합니다. 북한이 핵 개발 계획을 포기한다면, 국제사회는 북한이 원하는 많은 것을 제공할 것입니다. 북한은 핵무기를 보유할 것인지, 체제안전과 경제지원을 약속받을 것인지를 선택해야 합니다.아울러 저는 북한 핵 문제가 대화를 통해 평화적으로 해결되어야한다는 점을 거듭 강조하고자 합니다. 어떤 형태로든 군사적 긴장이 고조되어서는 안 됩니다. 북한 핵 문제가 대화를 통해 해결되도록, 우리는 미국,일본과의 공조를 강화할 것입니다. 중국, 러시아, 유럽연합 등과도 긴밀하게 협력해 나가겠습니다.올해는 한미동맹 50주년입니다. 한미동맹은 우리의 안전보장과 경제발전에 크게 기여해 왔습니다. 우리 국민은 이에 대해 깊이 감사하고 있습니다. 우리는 한미동맹을 소중히 발전시켜 나갈 것입니다. 호혜평등의 관계로 더욱 성숙시켜 나갈 것입니다. 전통우방을 비롯한 다른 국가들과의 관계도 확대해 나가겠습니다.국민 여러분.동북아 시대를 열고, 한반도에 평화를 정착시키려면, 우리 사회가 건강하고 미래지향적이어야 합니다. 힘과 비전을 가져야 합니다. 그러자면 개혁과 통합을 위한 지속적 노력이 필요합니다. 개혁은 성장의 동력이고, 통합은 도약의 디딤돌입니다.새 정부는 개혁과 통합을 바탕으로, 국민과 함께 하는 민주주의, 더불어 사는 균형발전사회, 평화와 번영의 동북아시대를 열어 나갈 것입니다. 이러한 목표로 가기 위해 저는 원칙과 신뢰, 공정과 투명, 대화와 타협, 분권과 자율을 새 정부 국정운영의 좌표로 삼고자 합니다.우리는 각 분야의 새로운 성장 동력을 창출해야 합니다. 외환위기를 초래했던 제반 요인들은 아직도 극복해야할 과제로 남아 있습니다. 시장과 제도를 세계기준에 맞게 공정하고 투명하게 개혁해, 기업하기 좋은 나라, 투자하고 싶은 나라로 만들고자 합니다.정치부터 바뀌어야 합니다. 진정으로 국민이 주인인 정치가 구현되어야 합니다. 당리당략보다 국리민복을 우선하는 정치풍토가 조성되어야 합니다. 대결과 갈등이 아니라 대화와 타협으로 문제를 푸는 정치문화가 자리잡았으면 합니다. 저부터 야당과 대화하고 타협하겠습니다.과학기술을 부단히 혁신해 '제2의 과학기술 입국'을 이루겠습니다. 지식정보화 기반을 지속적으로 확충하고 신산업을 육성하고자 합니다. 문화를 함양하고 문화산업의 발전도 적극 지원하겠습니다.이러한 국가목표에 부응할 수 있도록 교육도 혁신되어야 합니다. 우리 아이들이 입시지옥에서 벗어나 저마다의 소질과 창의력을 마음껏 발휘할 수 있게 해주어야 합니다.경제의 지속적 성장을 위해서도, 사회의 건강을 위해서도 부정부패를 없애야 합니다. 이를 위한 구조적 제도적 대안을 모색하겠습니다. 특히 사회지도층의 뼈를 깎는 성찰을 요망합니 ...

# %%
# 명사추출하기
word_list = word.nouns(report)
word_list
# Out:
# ['존경',
#  '국민',
#  '여러분',
#  '오늘',
#  '저',
#  '대한민국',
#  '제',
#  '대통령',
#  '취임',
#  '위해',
#  '이',
#  '자리',
#  '국민',
#  '여러분',
#  '선택',
#  '저',
#  '대한민국',
#  '새',
#  '정부',
#  '운영',
#  '영광',
#  '책임',
#  '국민',
#  '여러분',
#  '감사',
#  '이',
#  '소명',
#  '국민',
#  '여러분',
#  '완수',
#  '것임',
#  '약속',
#  '이',
#  '자리',
#  '참석',
#  '주신',
#  '김대중',
#  '대통령',
#  '비롯',
#  '전임',
#  '대통령',
#  '여러분',
#  '고이즈미',
#  '준',
#  '이치로',
#  '일본',
#  '총리',
#  '비롯',
#  '세계',
#  '각국',
#  '경축',
#  '사절',
#  '내외',
#  '귀빈',
#  '여러분',
#  '도',
#  '감사',
#  '이',
#  '자리',
#  '대구',
#  '지하철',
#  '참사',
#  '희생',
#  '여러분',
#  '명복',
#  '유가족',
#  '여러분',
#  '도',
#  '위로',
#  '불행',
#  '되풀이',
#  '재난',
#  '관리',
#  '체계',
#  '전면',
#  '점검',
#  '획기',
#  '개선',
#  '사회',
#  '최선',
#  '국민',
#  '여러분',
#  '우리',
#  '역사',
#  '도전',
#  '극복',
#  '연속',
#  '열강',
#  '틈',
#  '한반도',
#  '숱',
#  '고난',
#  '반만년',
#  '동안',
#  '민족',
#  '자존',
#  '독자',
#  '문화',
#  '해방',
#  '이후',
#  '분단',
#  '전쟁',
#  '가난',
#  '반세기',
#  '세계',
#  '번',
#  '경제',
#  '강국',
#  '건설',
#  '우리',
#  '농경',
#  '시대',
#  '산업화',
#  '지식',
#  '정보화',
#  '시대',
#  '성공',
#  '진입',
#  '지금',
#  '우리',
#  '다시',
#  '세계사',
#  '전환',
#  '점',
#  '직면',
#  '도약',
#  '후퇴',
#  '평화',
#  '긴장',
#  '의',
#  '갈림길',
#  '세계',
#  '안보',
#  '상황',
#  '이라크',
#  '정세',
#  '북한',
#  '핵',
#  '문제',
#  '국제사회',
#  '우려',
#  '고조',
#  '우리',
#  '평화',
#  '더욱',
#  '뿌리',
#  '대외',
#  '경제',
#  '환경',
#  '선진국',
#  '영역',
#  '개척',
#  '후발국',
#  '추격',
#  '우리',
#  '성장',
#  '동력',
#  '발전',
#  '전략',
#  '요구',
#  '우리',
#  '사회',
#  '내부',
#  '국가',
#  '명운',
#  '결정',
#  '문제',
#  '이',
#  '과제',
#  '국민',
#  '여러분',
#  '지혜',
#  '결단',
#  '이',
#  '모든',
#  '도전',
#  '극복',
#  '우리',
#  '수',
#  '우리',
#  '국민',
#  '힘',
#  '합치',
#  '것',
#  '저력',
#  '우리',
#  '외환',
#  '위기',
#  '세계',
#  '가장',
#  '지난해',
#  '월드컵',
#  '강',
#  '신화',
#  '창조',
#  '대통령',
#  '선거',
#  '모든',
#  '과정',
#  '통해',
#  '참여',
#  '민주주의',
#  '꽃',
#  '존경',
#  '국민',
#  '여러분',
#  '이제',
#  '우리',
#  '미래',
#  '한반도',
#  '수',
#  '우리',
#  '앞',
#  '동북아',
#  '시대',
#  '도래',
#  '근대',
#  '이후',
#  '세계',
#  '변방',
#  '동북아',
#  '이제',
#  '세계',
#  '경제',
#  '활',
#  '세기',
#  '동북아',
#  '시대',
#  '것',
#  '세계',
#  '학',
#  '예측',
#  '착착',
#  '현실',
#  '동북아',
#  '규모',
#  '세계',
#  '차지',
#  '중',
#  '일',
#  '국',
#  '유럽연합',
#  '네',
#  '배',
#  '인구',
#  '살',
#  '우리',
#  '한반도',
#  '동북아',
#  '중심',
#  '자리',
#  '잡고',
#  '한반도',
#  '중국',
#  '일본',
#  '대륙',
#  '해양',
#  '다리',
#  '지정학적',
#  '위치',
#  '지난날',
#  '우리',
#  '고통',
#  '오늘날',
#  '오히려',
#  '기회',
#  '세기',
#  '동북아',
#  '시대',
#  '중심',
#  '역할',
#  '우리',
#  '요구',
#  '것',
#  '우리',
#  '고급',
#  '두뇌',
#  '창의력',
#  '세계',
#  '일류',
#  '정보화',
#  '기반',
#  '인천공항',
#  '부산',
#  '항',
#  '광양항',
#  '고속',
#  '철도',
#  '등',
#  '하늘',
#  '바다',
#  '땅',
#  '물류',
#  '기반',
#  '구비',
#  '세기',
#  '동북아',
#  '시대',
#  '주도',
#  '수',
#  '기본',
#  '조건',
#  '한반도',
#  '동북아',
#  '물류',
#  '금융',
#  '중심지',
#  '거듭',
#  '날',
#  '수',
#  '동북아',
#  '시대',
#  '경제',
#  '출발',
#  '동북아',
#  '번영',
#  '공동체',
#  '를',
#  '이',
#  '통해',
#  '세계',
#  '번영',
#  '기여',
#  '평화',
#  '공동체',
#  '로',
#  '발전',
#  '지금',
#  '유럽연합',
#  '평화',
#  '공생',
#  '질서',
#  '동북아',
#  '구축',
#  '것',
#  '저',
#  '꿈',
#  '동북아',
#  '시대',
#  '완성',
#  '날',
#  '저',
#  '혼신',
#  '노력',
#  '것임',
#  '약속',
#  '국민',
#  '여러분',
#  '동북아',
#  '시대',
#  '열자',
#  '먼저',
#  '한반도',
#  '평화',
#  '제도',
#  '정착',
#  '한반도',
#  '지구',
#  '상의',
#  '마지막',
#  '냉전',
#  '지대',
#  '것',
#  '세기',
#  '유산',
#  '한반도',
#  '세기',
#  '세계',
#  '향',
#  '평화',
#  '발신',
#  '평화',
#  '지대',
#  '유라시아',
#  '대륙',
#  '태평양',
#  '동북아',
#  '관문',
#  '부산',
#  '파리',
#  '행',
#  '기차표',
#  '사서',
#  '평양',
#  '신의주',
#  '중국',
#  '몽골',
#  '러시아',
#  '유럽',
#  '복판',
#  '도착',
#  '날',
#  '이제',
#  '우리',
#  '한반도',
#  '평화',
#  '증진',
#  '위해',
#  '노력',
#  '그',
#  '성과',
#  '괄목',
#  '만',
#  '남북한',
#  '사이',
#  '사람과',
#  '물자',
#  '교류',
#  '일상',
#  '처럼',
#  '빈번',
#  '하늘',
#  '바다',
#  '땅',
#  '길이',
#  '모두',
#  '정책',
#  '추진',
#  '과정',
#  '더욱',
#  '국민',
#  '합의',
#  '과제',
#  '저',
#  '그동안',
#  '성과',
#  '계승',
#  '발전',
#  '정책',
#  '추진',
#  '방식',
#  '개선',
#  '저',
#  '한반도',
#  '평화',
#  '증진',
#  '번영',
#  '목표',
#  '평화',
#  '번영',
#  '정책',
#  '가지',
#  '원칙',
#  '가지',
#  '추진',
#  '첫째',
#  '모든',
#  '현안',
#  '대화',
#  '통해',
#  '둘째',
#  '상호',
#  '신뢰',
#  '호',
#  '혜주',
#  '를',
#  '실천',
#  '남북',
#  '당사자',
#  '원칙',
#  '기초',
#  '국제',
#  '협력',
#  '추구',
#  '넷째',
#  '내외',
#  '투명',
#  '높이',
#  '국민',
#  '참여',
#  '확대',
#  '초당',
#  '협력',
#  '국민',
#  '평화',
#  '번영',
#  '정책',
#  '이',
#  '북한',
#  '핵무기',
#  '개발',
#  '의혹',
#  '한반도',
#  '비롯',
#  '동북아',
#  '세계',
#  '평화',
#  '위협',
#  '북한',
#  '핵',
#  '개발',
#  '용인',
#  '수',
#  '북한',
#  '핵',
#  '개발',
#  '계획',
#  '포기',
#  '북한',
#  '핵',
#  '개발',
#  '계획',
#  '포기',
#  '국제사회',
#  '북한',
#  '것',
#  '제공',
#  '것',
#  '북한',
#  '핵무기',
#  '보유',
#  '것',
#  '체제',
#  '안전',
#  '지원',
#  '약속',
#  '것',
#  '인지',
#  '선택',
#  '저',
#  '북한',
#  '핵',
#  '문제',
#  '대화',
#  '통해',
#  '평화',
#  '해결',
#  '점',
#  '거듭',
#  '강조',
#  '형태',
#  '로',
#  '군사',
#  '긴장',
#  '고조',
#  '안',
#  '북한',
#  '핵',
#  '문제',
#  '대화',
#  '통해',
#  '해결',
#  '우리',
#  '미국',
#  '일본',
#  '공조',
#  '것',
#  '중국',
#  '러시아',
#  '유럽연합',
#  '등',
#  '협력',
#  '올해',
#  '한미',
#  '동맹',
#  '주년',
#  '한미',
#  '동맹',
#  '우리',
#  '안전보장',
#  '발전',
#  '크게',
#  '기여',
#  '우리',
#  '국민',
#  '이',
#  '대해',
#  '깊이',
#  '우리',
#  '한미',
#  '동맹',
#  '발전',
#  '것',
#  '호혜평등',
#  '관계',
#  '더욱',
#  '성숙',
#  '것',
#  '전통',
#  '우방',
#  '비롯',
#  '다른',
#  '국가',
#  '관계도',
#  '확대',
#  '국민',
#  '여러분',
#  '동북아',
#  '시대',
#  '한반도',
#  '평화',
#  '정착',
#  '우리',
#  '사회',
#  '미래',
#  '지향',
#  '힘',
#  '개혁',
#  '통합',
#  '위',
#  '지속',
#  '노력',
#  '개혁',
#  '성장',
#  '동력',
#  '통합',
#  '도약',
#  '디딤돌',
#  '새',
#  '정부',
#  '개혁',
#  '통합',
#  '바탕',
#  '국민',
#  '민주주의',
#  '균형발전',
#  '사회',
#  '평화',
#  '번영',
#  '동북아',
#  '시대',
#  '것',
#  '목표',
#  '가기',
#  '위해',
#  '저',
#  '원칙',
#  '신뢰',
#  '공정',
#  '투명',
#  '대화',
#  '타협',
#  '분권',
#  '자율',
#  '새',
#  '정부',
#  '국정',
#  '운영',
#  '좌표',
#  '삼고',
#  '우리',
#  '각',
#  '분야',
#  '성장',
#  '동력',
#  '창',
#  '외환위기',
#  '초래',
#  '제반',
#  '요인',
#  '극복',
#  '과제',
#  '남아',
#  '시장',
#  '제도',
#  '세계',
#  '기준',
#  '개혁',
#  '기업',
#  '나라',
#  '투자',
#  '나라',
#  '정치',
#  '진정',
#  '국민',
#  '주인',
#  '정치가',
#  '구현',
#  '리',
#  '략',
#  '국',
#  '리민',
#  '복',
#  '정치',
#  '풍토',
#  '조성',
#  '대결',
#  '갈등',
#  '대화',
#  '타협',
#  '문제',
#  '정치',
#  '문화',
#  '자리',
#  '저',
#  '야당',
#  '대화',
#  '타협',
#  '과학기술',
#  '혁신',
#  '제',
#  '의',
#  '과학기술',
#  '입국',
#  '지식',
#  '정보화',
#  '기반',
#  '지속',
#  '확충',
#  '산업',
#  '육성',
#  '문화',
#  '함양',
#  '문화',
#  '산업',
#  '발전',
#  '적극',
#  '지원',
#  '국가',
#  '목표',
#  '부응',
#  '수',
#  '교육',
#  '혁신',
#  '우리',
#  '아이',
#  '입시',
#  '지옥',
#  '저',
#  '소질',
#  '창의력',
#  '마음껏',
#  '발휘',
#  '수',
#  '경제',
#  '지속',
#  '성장',
#  '위',
#  '사회',
#  '건강',
#  '위',
#  '부정부패',
#  '위',
#  '구조',
#  '제도',
#  '대안',
#  '모색',
#  '회지',
#  '층',
#  '뼈',
#  '성찰',
#  '요망',
#  '중앙',
#  '집권',
#  '수도권',
#  '집중',
#  '국가',
#  '미래',
#  '위해',
#  '더',
#  '이상',
#  '방치',
#  '수',
#  '지방',
#  '분권',
#  '국가',
#  '균형발전',
#  '수',
#  '과제',
#  '중앙',
#  '지방',
#  '조화',
#  '균형',
#  '발전',
#  '지방',
#  '자신',
#  '미래',
#  '자율',
#  '설계',
#  '중앙',
#  '도',
#  '저',
#  '결의',
#  '추진',
#  '것',
#  '국민',
#  '통합',
#  '이',
#  '시대',
#  '가장',
#  '숙제',
#  '지역구',
#  '완화',
#  '위해',
#  '새',
#  '정부',
#  '지역',
#  '탕평',
#  '인사',
#  '포함',
#  '모든',
#  '조치',
#  '취해',
#  '것',
#  '소득',
#  '격차',
#  '비롯',
#  '계층',
#  '격차',
#  '위해',
#  '교육',
#  '세제',
#  '등',
#  '개선',
#  '강구',
#  '고자',
#  '노사',
#  '화합',
#  '협력',
#  '문화',
#  '노사',
#  '여러분',
#  '최선',
#  '노약',
#  '비롯',
#  '소외',
#  '사람',
#  '더',
#  '관심',
#  '사회',
#  '위해',
#  '복지',
#  '정책',
#  '모든',
#  '종류',
#  '불합리',
#  '차별',
#  '양성평등',
#  '사회',
#  '지향',
#  '개방',
#  '시대',
#  '농어',
#  '업',
#  '농',
#  '어민',
#  '위',
#  '대책',
#  '강구',
#  '고령',
#  '사회',
#  '도래',
#  '대한',
#  '준비',
#  '반칙',
#  '특권',
#  '용납',
#  '시대',
#  '이제',
#  '정의',
#  '기회',
#  '주의자',
#  '득세',
#  '굴절',
#  '풍토',
#  '청산',
#  '원칙',
#  '바로',
#  '신뢰',
#  '사회',
#  '만듭시',
#  '노력',
#  '사람',
#  '사회',
#  '대다수',
#  '국민',
#  '보람',
#  '존경',
#  '국민',
#  '여러분',
#  '세월',
#  '동안',
#  '우리',
#  '변방',
#  '역사',
#  '때로는',
#  '자신',
#  '운명',
#  '스스로',
#  '결정',
#  '의존',
#  '역사',
#  '강요',
#  '이제',
#  '우리',
#  '전기',
#  '세기',
#  '동북아',
#  '시대',
#  '중심',
#  '국가',
#  '웅비',
#  '기회',
#  '우리',
#  '우리',
#  '이',
#  '기회',
#  '나가야',
#  '우리',
#  '도전',
#  '극복',
#  '저력',
#  '위기',
#  '기회',
#  '지혜',
#  '지혜',
#  '저력',
#  '오늘',
#  '우리',
#  '도전',
#  '복합',
#  '시',
#  '오늘',
#  '우리',
#  '선조',
#  '기리',
#  '것',
#  '훗날',
#  '후손',
#  '오늘',
#  '우리',
#  '조상',
#  '기억',
#  '우리',
#  '마음',
#  '합치',
#  '기적',
#  '국민',
#  '우리',
#  '모두',
#  '마음',
#  '평화',
#  '번영',
#  '도약',
#  '새',
#  '역사',
#  '이',
#  '도정',
#  '모두',
#  '동참',
#  '항상',
#  '국민',
#  '여러분']

# %%
# 단어 빈도 체크
word_count = Counter(word_list)
word_count
# Out:
# Counter({'존경': 3,
#          '국민': 21,
#          '여러분': 16,
#          '오늘': 4,
#          '저': 11,
#          '대한민국': 2,
#          '제': 2,
#          '대통령': 4,
#          '취임': 1,
#          '위해': 7,
#          '이': 12,
#          '자리': 5,
#          '선택': 2,
#          '새': 5,
#          '정부': 4,
#          '운영': 2,
#          '영광': 1,
#          '책임': 1,
#          '감사': 2,
#          '소명': 1,
#          '완수': 1,
#          '것임': 2,
#          '약속': 3,
#          '참석': 1,
#          '주신': 1,
#          '김대중': 1,
#          '비롯': 6,
#          '전임': 1,
#          '고이즈미': 1,
#          '준': 1,
#          '이치로': 1,
#          '일본': 3,
#          '총리': 1,
#          '세계': 13,
#          '각국': 1,
#          '경축': 1,
#          '사절': 1,
#          '내외': 2,
#          '귀빈': 1,
#          '도': 3,
#          '대구': 1,
#          '지하철': 1,
#          '참사': 1,
#          '희생': 1,
#          '명복': 1,
#          '유가족': 1,
#          '위로': 1,
#          '불행': 1,
#          '되풀이': 1,
#          '재난': 1,
#          '관리': 1,
#          '체계': 1,
#          '전면': 1,
#          '점검': 1,
#          '획기': 1,
#          '개선': 3,
#          '사회': 10,
#          '최선': 2,
#          '우리': 33,
#          '역사': 4,
#          '도전': 4,
#          '극복': 4,
#          '연속': 1,
#          '열강': 1,
#          '틈': 1,
#          '한반도': 12,
#          '숱': 1,
#          '고난': 1,
#          '반만년': 1,
#          '동안': 2,
#          '민족': 1,
#          '자존': 1,
#          '독자': 1,
#          '문화': 5,
#          '해방': 1,
#          '이후': 2,
#          '분단': 1,
#          '전쟁': 1,
#          '가난': 1,
#          '반세기': 1,
#          '번': 1,
#          '경제': 5,
#          '강국': 1,
#          '건설': 1,
#          '농경': 1,
#          '시대': 15,
#          '산업화': 1,
#          '지식': 2,
#          '정보화': 3,
#          '성공': 1,
#          '진입': 1,
#          '지금': 2,
#          '다시': 1,
#          '세계사': 1,
#          '전환': 1,
#          '점': 2,
#          '직면': 1,
#          '도약': 3,
#          '후퇴': 1,
#          '평화': 16,
#          '긴장': 2,
#          '의': 2,
#          '갈림길': 1,
#          '안보': 1,
#          '상황': 1,
#          '이라크': 1,
#          '정세': 1,
#          '북한': 9,
#          '핵': 6,
#          '문제': 5,
#          '국제사회': 2,
#          '우려': 1,
#          '고조': 2,
#          '더욱': 3,
#          '뿌리': 1,
#          '대외': 1,
#          '환경': 1,
#          '선진국': 1,
#          '영역': 1,
#          '개척': 1,
#          '후발국': 1,
#          '추격': 1,
#          '성장': 4,
#          '동력': 3,
#          '발전': 7,
#          '전략': 1,
#          '요구': 2,
#          '내부': 1,
#          '국가': 6,
#          '명운': 1,
#          '결정': 2,
#          '과제': 4,
#          '지혜': 3,
#          '결단': 1,
#          '모든': 5,
#          '수': 9,
#          '힘': 2,
#          '합치': 2,
#          '것': 16,
#          '저력': 3,
#          '외환': 1,
#          '위기': 2,
#          '가장': 2,
#          '지난해': 1,
#          '월드컵': 1,
#          '강': 1,
#          '신화': 1,
#          '창조': 1,
#          '선거': 1,
#          '과정': 2,
#          '통해': 5,
#          '참여': 2,
#          '민주주의': 2,
#          '꽃': 1,
#          '이제': 5,
#          '미래': 4,
#          '앞': 1,
#          '동북아': 18,
#          '도래': 2,
#          '근대': 1,
#          '변방': 2,
#          '활': 1,
#          '세기': 6,
#          '학': 1,
#          '예측': 1,
#          '착착': 1,
#          '현실': 1,
#          '규모': 1,
#          '차지': 1,
#          '중': 1,
#          '일': 1,
#          '국': 2,
#          '유럽연합': 3,
#          '네': 1,
#          '배': 1,
#          '인구': 1,
#          '살': 1,
#          '중심': 3,
#          '잡고': 1,
#          '중국': 3,
#          '대륙': 2,
#          '해양': 1,
#          '다리': 1,
#          '지정학적': 1,
#          '위치': 1,
#          '지난날': 1,
#          '고통': 1,
#          '오늘날': 1,
#          '오히려': 1,
#          '기회': 5,
#          '역할': 1,
#          '고급': 1,
#          '두뇌': 1,
#          '창의력': 2,
#          '일류': 1,
#          '기반': 3,
#          '인천공항': 1,
#          '부산': 2,
#          '항': 1,
#          '광양항': 1,
#          '고속': 1,
#          '철도': 1,
#          '등': 3,
#          '하늘': 2,
#          '바다': 2,
#          '땅': 2,
#          '물류': 2,
#          '구비': 1,
#          '주도': 1,
#          '기본': 1,
#          '조건': 1,
#          '금융': 1,
#          '중심지': 1,
#          '거듭': 2,
#          '날': 3,
#          '출발': 1,
#          '번영': 7,
#          '공동체': 2,
#          '를': 2,
#          '기여': 2,
#          '로': 2,
#          '공생': 1,
#          '질서': 1,
#          '구축': 1,
#          '꿈': 1,
#          '완성': 1,
#          '혼신': 1,
#          '노력': 4,
#          '열자': 1,
#          '먼저': 1,
#          '제도': 3,
#          '정착': 2,
#          '지구': 1,
#          '상의': 1,
#          '마지막': 1,
#          '냉전': 1,
#          '지대': 2,
#          '유산': 1,
#          '향': 1,
#          '발신': 1,
#          '유라시아': 1,
#          '태평양': 1,
#          '관문': 1,
#          '파리': 1,
#          '행': 1,
#          '기차표': 1,
#          '사서': 1,
#          '평양': 1,
#          '신의주': 1,
#          '몽골': 1,
#          '러시아': 2,
#          '유럽': 1,
#          '복판': 1,
#          '도착': 1,
#          '증진': 2,
#          '그': 1,
#          '성과': 2,
#          '괄목': 1,
#          '만': 1,
#          '남북한': 1,
#          '사이': 1,
#          '사람과': 1,
#          '물자': 1,
#          '교류': 1,
#          '일상': 1,
#          '처럼': 1,
#          '빈번': 1,
#          '길이': 1,
#          '모두': 3,
#          '정책': 5,
#          '추진': 4,
#          '합의': 1,
#          '그동안': 1,
#          '계승': 1,
#          '방식': 1,
#          '목표': 3,
#          '가지': 2,
#          '원칙': 4,
#          '첫째': 1,
#          '현안': 1,
#          '대화': 6,
#          '둘째': 1,
#          '상호': 1,
#          '신뢰': 3,
#          '호': 1,
#          '혜주': 1,
#          '실천': 1,
#          '남북': 1,
#          '당사자': 1,
#          '기초': 1,
#          '국제': 1,
#          '협력': 4,
#          '추구': 1,
#          '넷째': 1,
#          '투명': 2,
#          '높이': 1,
#          '확대': 2,
#          '초당': 1,
#          '핵무기': 2,
#          '개발': 4,
#          '의혹': 1,
#          '위협': 1,
#          '용인': 1,
#          '계획': 2,
#          '포기': 2,
#          '제공': 1,
#          '보유': 1,
#          '체제': 1,
#          '안전': 1,
#          '지원': 2,
#          '인지': 1,
#          '해결': 2,
#          '강조': 1,
#          '형태': 1,
#          '군사': 1,
#          '안': 1,
#          '미국': 1,
#          '공조': 1,
#          '올해': 1,
#          '한미': 3,
#          '동맹': 3,
#          '주년': 1,
#          '안전보장': 1,
#          '크게': 1,
#          '대해': 1,
#          '깊이': 1,
#          '호혜평등': 1,
#          '관계': 1,
#          '성숙': 1,
#          '전통': 1,
#          '우방': 1,
#          '다른': 1,
#          '관계도': 1,
#          '지향': 2,
#          '개혁': 4,
#          '통합': 4,
#          '위': 5,
#          '지속': 3,
#          '디딤돌': 1,
#          '바탕': 1,
#          '균형발전': 2,
#          '가기': 1,
#          '공정': 1,
#          '타협': 3,
#          '분권': 2,
#          '자율': 2,
#          '국정': 1,
#          '좌표': 1,
#          '삼고': 1,
#          '각': 1,
#          '분야': 1,
#          '창': 1,
#          '외환위기': 1,
#          '초래': 1,
#          '제반': 1,
#          '요인': 1,
#          '남아': 1,
#          '시장': 1,
#          '기준': 1,
#          '기업': 1,
#          '나라': 2,
#          '투자': 1,
#          '정치': 3,
#          '진정': 1,
#          '주인': 1,
#          '정치가': 1,
#          '구현': 1,
#          '리': 1,
#          '략': 1,
#          '리민': 1,
#          '복': 1,
#          '풍토': 2,
#          '조성': 1,
#          '대결': 1,
#          '갈등': 1,
#          '야당': 1,
#          '과학기술': 2,
#          '혁신': 2,
#          '입국': 1,
#          '확충': 1,
#          '산업': 2,
#          '육성': 1,
#          '함양': 1,
#          '적극': 1,
#          '부응': 1,
#          '교육': 2,
#          '아이': 1,
#          '입시': 1,
#          '지옥': 1,
#          '소질': 1,
#          '마음껏': 1,
#          '발휘': 1,
#          '건강': 1,
#          '부정부패': 1,
#          '구조': 1,
#          '대안': 1,
#          '모색': 1,
#          '회지': 1,
#          '층': 1,
#          '뼈': 1,
#          '성찰': 1,
#          '요망': 1,
#          '중앙': 3,
#          '집권': 1,
#          '수도권': 1,
#          '집중': 1,
#          '더': 2,
#          '이상': 1,
#          '방치': 1,
#          '지방': 3,
#          '조화': 1,
#          '균형': 1,
#          '자신': 2,
#          '설계': 1,
#          '결의': 1,
#          '숙제': 1,
#          '지역구': 1,
#          '완화': 1,
#          '지역': 1,
#          '탕평': 1,
#          '인사': 1,
#          '포함': 1,
#          '조치': 1,
#          '취해': 1,
#          '소득': 1,
#          '격차': 2,
#          '계층': 1,
#          '세제': 1,
#          '강구': 2,
#          '고자': 1,
#          '노사': 2,
#          '화합': 1,
#          '노약': 1,
#          '소외': 1,
#          '사람': 2,
#          '관심': 1,
#          '복지': 1,
#          '종류': 1,
#          '불합리': 1,
#          '차별': 1,
#          '양성평등': 1,
#          '개방': 1,
#          '농어': 1,
#          '업': 1,
#          '농': 1,
#          '어민': 1,
#          '대책': 1,
#          '고령': 1,
#          '대한': 1,
#          '준비': 1,
#          '반칙': 1,
#          '특권': 1,
#          '용납': 1,
#          '정의': 1,
#          '주의자': 1,
#          '득세': 1,
#          '굴절': 1,
#          '청산': 1,
#          '바로': 1,
#          '만듭시': 1,
#          '대다수': 1,
#          '보람': 1,
#          '세월': 1,
#          '때로는': 1,
#          '운명': 1,
#          '스스로': 1,
#          '의존': 1,
#          '강요': 1,
#          '전기': 1,
#          '웅비': 1,
#          '나가야': 1,
#          '복합': 1,
#          '시': 1,
#          '선조': 1,
#          '기리': 1,
#          '훗날': 1,
#          '후손': 1,
#          '조상': 1,
#          '기억': 1,
#          '마음': 2,
#          '기적': 1,
#          '도정': 1,
#          '동참': 1,
#          '항상': 1})

# %%
# 1자리 단어 제거하기
word_list_finaly = []

#word_list: 명사추출했던 변수 
for w in word_list:
    if len(w) > 1:
        word_list_finaly.append(w)

# %%
word_list_finaly = Counter(word_list_finaly)

# %%
word_list_finaly
# Out:
# Counter({'존경': 3,
#          '국민': 21,
#          '여러분': 16,
#          '오늘': 4,
#          '대한민국': 2,
#          '대통령': 4,
#          '취임': 1,
#          '위해': 7,
#          '자리': 5,
#          '선택': 2,
#          '정부': 4,
#          '운영': 2,
#          '영광': 1,
#          '책임': 1,
#          '감사': 2,
#          '소명': 1,
#          '완수': 1,
#          '것임': 2,
#          '약속': 3,
#          '참석': 1,
#          '주신': 1,
#          '김대중': 1,
#          '비롯': 6,
#          '전임': 1,
#          '고이즈미': 1,
#          '이치로': 1,
#          '일본': 3,
#          '총리': 1,
#          '세계': 13,
#          '각국': 1,
#          '경축': 1,
#          '사절': 1,
#          '내외': 2,
#          '귀빈': 1,
#          '대구': 1,
#          '지하철': 1,
#          '참사': 1,
#          '희생': 1,
#          '명복': 1,
#          '유가족': 1,
#          '위로': 1,
#          '불행': 1,
#          '되풀이': 1,
#          '재난': 1,
#          '관리': 1,
#          '체계': 1,
#          '전면': 1,
#          '점검': 1,
#          '획기': 1,
#          '개선': 3,
#          '사회': 10,
#          '최선': 2,
#          '우리': 33,
#          '역사': 4,
#          '도전': 4,
#          '극복': 4,
#          '연속': 1,
#          '열강': 1,
#          '한반도': 12,
#          '고난': 1,
#          '반만년': 1,
#          '동안': 2,
#          '민족': 1,
#          '자존': 1,
#          '독자': 1,
#          '문화': 5,
#          '해방': 1,
#          '이후': 2,
#          '분단': 1,
#          '전쟁': 1,
#          '가난': 1,
#          '반세기': 1,
#          '경제': 5,
#          '강국': 1,
#          '건설': 1,
#          '농경': 1,
#          '시대': 15,
#          '산업화': 1,
#          '지식': 2,
#          '정보화': 3,
#          '성공': 1,
#          '진입': 1,
#          '지금': 2,
#          '다시': 1,
#          '세계사': 1,
#          '전환': 1,
#          '직면': 1,
#          '도약': 3,
#          '후퇴': 1,
#          '평화': 16,
#          '긴장': 2,
#          '갈림길': 1,
#          '안보': 1,
#          '상황': 1,
#          '이라크': 1,
#          '정세': 1,
#          '북한': 9,
#          '문제': 5,
#          '국제사회': 2,
#          '우려': 1,
#          '고조': 2,
#          '더욱': 3,
#          '뿌리': 1,
#          '대외': 1,
#          '환경': 1,
#          '선진국': 1,
#          '영역': 1,
#          '개척': 1,
#          '후발국': 1,
#          '추격': 1,
#          '성장': 4,
#          '동력': 3,
#          '발전': 7,
#          '전략': 1,
#          '요구': 2,
#          '내부': 1,
#          '국가': 6,
#          '명운': 1,
#          '결정': 2,
#          '과제': 4,
#          '지혜': 3,
#          '결단': 1,
#          '모든': 5,
#          '합치': 2,
#          '저력': 3,
#          '외환': 1,
#          '위기': 2,
#          '가장': 2,
#          '지난해': 1,
#          '월드컵': 1,
#          '신화': 1,
#          '창조': 1,
#          '선거': 1,
#          '과정': 2,
#          '통해': 5,
#          '참여': 2,
#          '민주주의': 2,
#          '이제': 5,
#          '미래': 4,
#          '동북아': 18,
#          '도래': 2,
#          '근대': 1,
#          '변방': 2,
#          '세기': 6,
#          '예측': 1,
#          '착착': 1,
#          '현실': 1,
#          '규모': 1,
#          '차지': 1,
#          '유럽연합': 3,
#          '인구': 1,
#          '중심': 3,
#          '잡고': 1,
#          '중국': 3,
#          '대륙': 2,
#          '해양': 1,
#          '다리': 1,
#          '지정학적': 1,
#          '위치': 1,
#          '지난날': 1,
#          '고통': 1,
#          '오늘날': 1,
#          '오히려': 1,
#          '기회': 5,
#          '역할': 1,
#          '고급': 1,
#          '두뇌': 1,
#          '창의력': 2,
#          '일류': 1,
#          '기반': 3,
#          '인천공항': 1,
#          '부산': 2,
#          '광양항': 1,
#          '고속': 1,
#          '철도': 1,
#          '하늘': 2,
#          '바다': 2,
#          '물류': 2,
#          '구비': 1,
#          '주도': 1,
#          '기본': 1,
#          '조건': 1,
#          '금융': 1,
#          '중심지': 1,
#          '거듭': 2,
#          '출발': 1,
#          '번영': 7,
#          '공동체': 2,
#          '기여': 2,
#          '공생': 1,
#          '질서': 1,
#          '구축': 1,
#          '완성': 1,
#          '혼신': 1,
#          '노력': 4,
#          '열자': 1,
#          '먼저': 1,
#          '제도': 3,
#          '정착': 2,
#          '지구': 1,
#          '상의': 1,
#          '마지막': 1,
#          '냉전': 1,
#          '지대': 2,
#          '유산': 1,
#          '발신': 1,
#          '유라시아': 1,
#          '태평양': 1,
#          '관문': 1,
#          '파리': 1,
#          '기차표': 1,
#          '사서': 1,
#          '평양': 1,
#          '신의주': 1,
#          '몽골': 1,
#          '러시아': 2,
#          '유럽': 1,
#          '복판': 1,
#          '도착': 1,
#          '증진': 2,
#          '성과': 2,
#          '괄목': 1,
#          '남북한': 1,
#          '사이': 1,
#          '사람과': 1,
#          '물자': 1,
#          '교류': 1,
#          '일상': 1,
#          '처럼': 1,
#          '빈번': 1,
#          '길이': 1,
#          '모두': 3,
#          '정책': 5,
#          '추진': 4,
#          '합의': 1,
#          '그동안': 1,
#          '계승': 1,
#          '방식': 1,
#          '목표': 3,
#          '가지': 2,
#          '원칙': 4,
#          '첫째': 1,
#          '현안': 1,
#          '대화': 6,
#          '둘째': 1,
#          '상호': 1,
#          '신뢰': 3,
#          '혜주': 1,
#          '실천': 1,
#          '남북': 1,
#          '당사자': 1,
#          '기초': 1,
#          '국제': 1,
#          '협력': 4,
#          '추구': 1,
#          '넷째': 1,
#          '투명': 2,
#          '높이': 1,
#          '확대': 2,
#          '초당': 1,
#          '핵무기': 2,
#          '개발': 4,
#          '의혹': 1,
#          '위협': 1,
#          '용인': 1,
#          '계획': 2,
#          '포기': 2,
#          '제공': 1,
#          '보유': 1,
#          '체제': 1,
#          '안전': 1,
#          '지원': 2,
#          '인지': 1,
#          '해결': 2,
#          '강조': 1,
#          '형태': 1,
#          '군사': 1,
#          '미국': 1,
#          '공조': 1,
#          '올해': 1,
#          '한미': 3,
#          '동맹': 3,
#          '주년': 1,
#          '안전보장': 1,
#          '크게': 1,
#          '대해': 1,
#          '깊이': 1,
#          '호혜평등': 1,
#          '관계': 1,
#          '성숙': 1,
#          '전통': 1,
#          '우방': 1,
#          '다른': 1,
#          '관계도': 1,
#          '지향': 2,
#          '개혁': 4,
#          '통합': 4,
#          '지속': 3,
#          '디딤돌': 1,
#          '바탕': 1,
#          '균형발전': 2,
#          '가기': 1,
#          '공정': 1,
#          '타협': 3,
#          '분권': 2,
#          '자율': 2,
#          '국정': 1,
#          '좌표': 1,
#          '삼고': 1,
#          '분야': 1,
#          '외환위기': 1,
#          '초래': 1,
#          '제반': 1,
#          '요인': 1,
#          '남아': 1,
#          '시장': 1,
#          '기준': 1,
#          '기업': 1,
#          '나라': 2,
#          '투자': 1,
#          '정치': 3,
#          '진정': 1,
#          '주인': 1,
#          '정치가': 1,
#          '구현': 1,
#          '리민': 1,
#          '풍토': 2,
#          '조성': 1,
#          '대결': 1,
#          '갈등': 1,
#          '야당': 1,
#          '과학기술': 2,
#          '혁신': 2,
#          '입국': 1,
#          '확충': 1,
#          '산업': 2,
#          '육성': 1,
#          '함양': 1,
#          '적극': 1,
#          '부응': 1,
#          '교육': 2,
#          '아이': 1,
#          '입시': 1,
#          '지옥': 1,
#          '소질': 1,
#          '마음껏': 1,
#          '발휘': 1,
#          '건강': 1,
#          '부정부패': 1,
#          '구조': 1,
#          '대안': 1,
#          '모색': 1,
#          '회지': 1,
#          '성찰': 1,
#          '요망': 1,
#          '중앙': 3,
#          '집권': 1,
#          '수도권': 1,
#          '집중': 1,
#          '이상': 1,
#          '방치': 1,
#          '지방': 3,
#          '조화': 1,
#          '균형': 1,
#          '자신': 2,
#          '설계': 1,
#          '결의': 1,
#          '숙제': 1,
#          '지역구': 1,
#          '완화': 1,
#          '지역': 1,
#          '탕평': 1,
#          '인사': 1,
#          '포함': 1,
#          '조치': 1,
#          '취해': 1,
#          '소득': 1,
#          '격차': 2,
#          '계층': 1,
#          '세제': 1,
#          '강구': 2,
#          '고자': 1,
#          '노사': 2,
#          '화합': 1,
#          '노약': 1,
#          '소외': 1,
#          '사람': 2,
#          '관심': 1,
#          '복지': 1,
#          '종류': 1,
#          '불합리': 1,
#          '차별': 1,
#          '양성평등': 1,
#          '개방': 1,
#          '농어': 1,
#          '어민': 1,
#          '대책': 1,
#          '고령': 1,
#          '대한': 1,
#          '준비': 1,
#          '반칙': 1,
#          '특권': 1,
#          '용납': 1,
#          '정의': 1,
#          '주의자': 1,
#          '득세': 1,
#          '굴절': 1,
#          '청산': 1,
#          '바로': 1,
#          '만듭시': 1,
#          '대다수': 1,
#          '보람': 1,
#          '세월': 1,
#          '때로는': 1,
#          '운명': 1,
#          '스스로': 1,
#          '의존': 1,
#          '강요': 1,
#          '전기': 1,
#          '웅비': 1,
#          '나가야': 1,
#          '복합': 1,
#          '선조': 1,
#          '기리': 1,
#          '훗날': 1,
#          '후손': 1,
#          '조상': 1,
#          '기억': 1,
#          '마음': 2,
#          '기적': 1,
#          '도정': 1,
#          '동참': 1,
#          '항상': 1})

# %%
wordcloud = WordCloud(
        font_path = font_path,
        #배경색 
        background_color = "white",
        #사용할 워드의 갯수
        max_words = 30, 
        width = 300,
        height = 150
    ).generate_from_frequencies(word_list_finaly)
#그래프 크기 지정 
plt.figure(figsize=(15,10))
#그래프보여주기
plt.imshow(wordcloud)
#x축 y축을 보여줄것인가 말것인가..
plt.axis('off')
#이미지로 저장하기
plt.savefig("./report_wordcloud.png")

# %%
# 강아지 모양 워드클라우드 그리기
import stylecloud

# %%
#!pip install stylecloud
# Out:
# Collecting stylecloud
#   Downloading stylecloud-0.5.2.tar.gz (262 kB)
#      -------------------------------------- 262.1/262.1 KB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: wordcloud in c:\users\admin\anaconda3\envs\nltk\lib\site-packages (from stylecloud) (1.8.1)
# Collecting icon-font-to-png
#   Downloading icon_font_to_png-0.4.1-py2.py3-none-any.whl (161 kB)
#      -------------------------------------- 161.4/161.4 KB 4.7 MB/s eta 0:00:00
# Collecting palettable
#   Downloading palettable-3.3.0-py2.py3-none-any.whl (111 kB)
#      -------------------------------------- 111.8/111.8 KB 3.3 MB/s eta 0:00:00
# Collecting fire
#   Downloading fire-0.4.0.tar.gz (87 kB)
#      ---------------------------------------- 87.7/87.7 KB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: matplotlib in c:\users\admin\anaconda3\envs\nltk\lib\site-packages (from stylecloud) (3.5.1)
# Requirement already satisfied: six in c:\users\admin\anaconda3\envs\nltk\lib\site-packages (from fire->stylecloud) (1.16.0)
# Collecting termcolor
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting requests>=2.12.5
#   Using cached requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Requirement already satisfied: Pillow>=4.0.0 in c:\users\admin\anaconda3\envs\nltk\lib\site-packages (from icon-font-to-png->stylecloud) (9.0.1)
# Collecting tinycss>=0.4
#   Downloading tinycss-0.4.tar.gz (87 kB)
#      ---------------------------------------- 87.8/87.8 KB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\anaconda3\envs\nltk\lib\site-packages (from matplotlib->stylecloud) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\envs\nltk\lib\site-packages (from matplotlib->stylecloud) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\anaconda3\envs\nltk\lib\site-packages (from matplotlib->stylecloud) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\admin\anaconda3\envs\nltk\lib\site-packages (from matplotlib->stylecloud) (3.0.7)
# Requirement already satisfied: numpy>=1.17 in c:\users\admin\anaconda3\envs\nltk\lib\site-packages (from matplotlib->stylecloud) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\envs\nltk\lib\site-packages (from matplotlib->stylecloud) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\anaconda3\envs\nltk\lib\site-packages (from matplotlib->stylecloud) (4.31.2)
# Requirement already satisfied: typing-extensions in c:\users\admin\anaconda3\envs\nltk\lib\site-packages (from kiwisolver>=1.0.1->matplotlib->stylecloud) (4.1.1)
# Collecting idna<4,>=2.5
#   Using cached idna-3.3-py3-none-any.whl (61 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\envs\nltk\lib\site-packages (from requests>=2.12.5->icon-font-to-png->stylecloud) (2021.10.8)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
#      -------------------------------------- 139.0/139.0 KB 8.6 MB/s eta 0:00:00
# Building wheels for collected packages: stylecloud, fire, tinycss, termcolor
#   Building wheel for stylecloud (setup.py): started
#   Building wheel for stylecloud (setup.py): finished with status 'done'
#   Created wheel for stylecloud: filename=stylecloud-0.5.2-py3-none-any.whl size=259508 sha256=885dddc7c349d74410e4e1fcfe0dc3392e9ae2be92b079e9a835cbd086e0878c
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\77\42\7a\f52b5f84c04196fd4c2a3dceeb1bbeaee1c93a4fe271b5eb41
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115942 sha256=e1aa1256376d606e1f254b5a1a92089e76b6f8181b39dc3b7547cce462a8ac38
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\8a\67\fb\2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
#   Building wheel for tinycss (setup.py): started
#   Building wheel for tinycss (setup.py): finished with status 'done'
#   Created wheel for tinycss: filename=tinycss-0.4-py3-none-any.whl size=43955 sha256=c68b22cc1a27883d63c8f8962af2f1a9c03ff581259731d4168a97f683243da4
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\6c\66\e8\e53d7a476011891fa51a5ee83a2d1852b19b258f975055429b
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4848 sha256=91e0c58cd59ba128f575095ec9d60d372e40d1a5b161ea4dad6dc9af4e5dd792
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\3f\e3\ec\8a8336ff196023622fbcb36de0c5a5c218cbb24111d1d4c7f2
# Successfully built stylecloud fire tinycss termcolor
# Installing collected packages: tinycss, termcolor, palettable, urllib3, idna, fire, charset-normalizer, requests, icon-font-to-png, stylecloud
# Successfully installed charset-normalizer-2.0.12 fire-0.4.0 icon-font-to-png-0.4.1 idna-3.3 palettable-3.3.0 requests-2.27.1 stylecloud-0.5.2 termcolor-1.1.0 tinycss-0.4 urllib3-1.26.9

# %%
stylecloud.gen_stylecloud(
    text = word_list_finaly,
    # 워드클라우드 스타일 지정
    icon_name = "fas fa-dog",
    # 사용할 색상
    palette = "colorbrewer.diverging.Spectral_11",
    # 배경색
    background_color = "black",
    # 수직구조로 색상 전환
    gradient = "horizontal",
    #폰트 지정 
    font_path = font_path,
    #이미지로 저장시키기
    output_name = "./fa_dog_wordcloud.png"
)

# %%
stylecloud.gen_stylecloud(
    text = word_list_finaly,
    # 워드클라우드 스타일 지정
    icon_name = "fas fa-apple-alt",
    # 사용할 색상
    palette = "cartocolors.qualitative.Pastel_3",
    # 배경색
    background_color = "black",
    # 수직구조로 색상 전환
    gradient = "horizontal",
    #폰트 지정 
    font_path = font_path,
    #이미지로 저장시키기
    output_name = "./fa_apple_alt_wordcloud.png"
)
