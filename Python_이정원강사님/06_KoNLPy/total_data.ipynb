# %%
import pandas as pd
import os

# %%
print(os.listdir(os.getcwd()))
# Out:
# ['.ipynb_checkpoints', '01_웹크롤링.ipynb', '01_전처리_기본', '02_관광데이터분석', '03_심평원', '04_교통데이터분석', 'KoNLPy', 'Project', 'total_data.csv', 'total_data.ipynb', '회귀분석']

# %%
file_path = "./total_data.csv"
df = pd.read_csv(file_path,encoding="UTF-8")

df
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#           SALEDATE WHSAL_NM CMP_NM PUM_NM      KIND_NM DAN_NM POJ_NM SIZE_NM  \
# 0         20160109   부산엄궁도매   부산청과     수박  수박(일반)(꼭지절단     kg     상자       .
# 1         20160109   부산엄궁도매   부산청과     수박  수박(일반)(꼭지절단     kg     상자       .
# 2         20160109   부산엄궁도매   부산청과     수박  수박(일반)(꼭지절단     kg     상자       .
# 3         20160109   부산엄궁도매   부산청과     수박  수박(일반)(꼭지절단     kg     상자       .
# 4         20160109   부산엄궁도매   부산청과     수박  수박(일반)(꼭지절단     kg     상자       .
# ...            ...      ...    ...    ...          ...    ...    ...     ...
# 19340152  20191231   서울강서도매   강서청과     사과          미시마     kg      .       .
# 19340153  20191231   서울강서도매   강서청과     사과          미시마     kg      .       .
# ...
